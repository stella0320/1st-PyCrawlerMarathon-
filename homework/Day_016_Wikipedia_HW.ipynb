# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup
import os, sys

# %%
input_keyword = "網路爬蟲"  # 這裡可以自己定義有興趣的關鍵字

fh = open("../WikiArticle/"+ input_keyword + '.txt', 'w', encoding='utf-8' )

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# 網路爬蟲: %E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2
# /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# 網路爬蟲（英語：web crawler），也叫網路蜘蛛（spider），是一種用來自動瀏覽全球資訊網的網路機器人。其目的一般為編纂網路索引（英語：Web indexing）。
#
# 網路搜尋引擎等站點通過爬蟲軟體更新自身的網站內容（英語：Web content）或其對其他網站的索引。網路爬蟲可以將自己所存取的頁面儲存下來，以便搜尋引擎事後生成索引（英語：Index (search engine)）供用戶搜尋。
#
# 爬蟲存取網站的過程會消耗目標系統資源。不少網路系統並不默許爬蟲工作。因此在存取大量頁面時，爬蟲需要考慮到規劃、負載，還需要講「禮貌」。 不願意被爬蟲存取、被爬蟲主人知曉的公開站點可以使用robots.txt檔案之類的方法避免存取。這個檔案可以要求機器人（英語：Software agent）只對網站的一部分進行索引，或完全不作處理。
#
# 網際網路上的頁面極多，即使是最大的爬蟲系統也無法做出完整的索引。因此在公元2000年之前的全球資訊網出現初期，搜尋引擎經常找不到多少相關結果。現在的搜尋引擎在這方面已經進步很多，能夠即刻給出高品質結果。
#
# 爬蟲還可以驗證超連結和HTML代碼，用於網路抓取（英語：Web scraping）（參見資料驅動編程（英語：Data-driven programming））。
#
# 網路爬蟲也可稱作網路蜘蛛[1]、螞蟻、自動索引程式（automatic indexer）[2] ，或（在FOAF（英語：FOAF (software)）軟體中）稱為網路疾走（web scutter）。[3]
#
# 網路爬蟲始於一張被稱作種子的統一資源位址（URL）列表。當網路爬蟲存取這些統一資源定位器時，它們會甄別出頁面上所有的超連結，並將它們寫入一張「待訪列表」，即所謂爬行疆域（英語：crawl frontier）。此疆域上的URL將會被按照一套策略迴圈來存取。如果爬蟲在執行的過程中複製歸檔和儲存網站上的資訊，這些檔案通常儲存，使他們可以較容易的被檢視。閱讀和瀏覽他們儲存的網站上並即時更新的資訊，這些被儲存的網頁又被稱為「快照」。越大容量的網頁意味著網路爬蟲只能在給予的時間內下載越少部分的網頁，所以要優先考慮其下載。高變化率意味著網頁可能已經被更新或者被取代。一些伺服器端軟體生成的URL（統一資源定位符）也使得網路爬蟲很難避免檢索到重複內容。
#
# 但是網際網路的資源卷帙浩繁，這也意味著網路爬蟲只能在一定時間內下載有限數量的網頁，因此它需要衡量優先順序的下載方式。有時候網頁出現、更新和消失的速度很快，也就是說網路爬蟲下載的網頁在幾秒後就已經被修改或甚至刪除了。這些都是網路爬蟲設計師們所面臨的兩個問題。
#
# 再者，伺服器端軟體所生成的統一資源位址數量龐大，以至網路爬蟲難免也會採集到重複的內容。根據超文字傳輸協定，無盡組合的參數所返回的頁面中，只有很少一部分確實傳回正確的內容。例如：數張快照陳列室的網站，可能通過幾個參數，讓用戶選擇相關快照：其一是通過四種方法對快照排序，其二是關於快照解析度的的三種選擇，其三是兩種檔案格式，另加一個用戶可否提供內容的選擇，這樣對於同樣的結果會有48種（4*3*2）不同的統一資源位址與其關聯。這種數學組合替網路爬蟲造成了麻煩，因為它們必須越過這些無關指令碼變化的組合，尋找不重複的內容。
#
# 爬蟲的實現由以下策略組成：[4]
#
# 爬蟲可能只想搜尋HTML頁面而避免其他MIME 類型。為了只請求HTML資源，爬蟲在抓取整個以GET方式請求的資源之前，通過建立HTTP的HEAD請求來決定網路資源的MIME類型。為了避免發出過多的請求，爬蟲會檢查URL和只請求那些以某些字元（如.html, .htm, .asp, .aspx, .php, .jsp, .jspx 或 / ）作為字尾的URL。這個策略可能會跳過很多HTML網路資源。
#
# 有些爬蟲還能避免請求一些帶有「?」的資源（動態生成）。為了避免掉入從網站下載無限量的URL的爬蟲陷阱。不過假若網站重寫URL以簡化URL的目的，這個策略就變得不可靠了。
#
# 爬蟲通常使用某些URL規格化的方式以避免資源的重複爬取。URL規格化，指的是以某種一致的方式修改和標準化URL的過程。這個過程有各種各樣的處理規則，包括統一轉換為小寫、移除「.」和「..」片段，以及在非空路徑里插入斜杆。
#
# 有些爬蟲希望從指定的網站中儘可能地爬取資源。而路徑上移爬蟲就是為了能爬取每個URL里提示出的每個路徑。[5] 例如，給定一個Http的種子URL: http://llama.org/hamster/monkey/page.html ，要爬取 /hamster/monkey/ ， /hamster/ 和 / 。Cothey發現路徑能非常有效地爬取獨立的資源，或以某種規律無法在站內部連結接爬取到的資源。
#
# 對於爬蟲來說，一個頁面的重要性也可以說是，給定查詢條件一個頁面相似效能起到的作用。網路爬蟲要下載相似的網頁被稱為主題爬蟲或局部爬蟲。這個主題爬蟲或局部爬蟲的概念第一次被Filippo Menczer[6][7] 和  Soumen Chakrabarti 等人提出的。[8]
#
# 網站的屬性之一就是經常動態變化，而爬取網站的一小部分往往需要花費幾個星期或者幾個月。等到網站爬蟲完成它的爬取，很多事件也已經發生了，包括增加、更新和刪除。
# 在搜尋引擎的角度，因為沒有檢測這些變化，會導致儲存了過期資源的代價。最常用的估價函式是新鮮度和過時性。
# 新鮮度：這是一個衡量抓取內容是不是準確的二元值。在時間t內，倉庫中頁面p的新鮮度是這樣定義的：
#
# 過時性:這是一個衡量本地已抓取的內容過時程度的指標。在時間t時，倉庫中頁面p的時效性的定義如下：
#
# 爬蟲相比於人，可以有更快的檢索速度和更深的層次，所以，他們可能使一個站點癱瘓。不需要說一個單獨的爬蟲一秒鐘要執行多條請求，下載大的檔案。一個伺服器也會很難回應多執行緒爬蟲的請求。
# 就像Koster所注意的那樣，爬蟲的使用對很多工作都是很有用的，但是對一般的社區，也需要付出代價。使用爬蟲的代價包括：[9]
#
# 對這些問題的局部解決方法是漫遊器排除協定（Robots exclusion protocol），也被稱為robots.txt議定書[10]，這份協定是讓管理員指明網路伺服器的不應該爬取的約定。這個標準沒有包括重新存取一台伺服器的間隔的建議，雖然設定存取間隔是避免伺服器超載的最有效辦法。最近的商業搜尋引擎，如Google，Ask Jeeves，MSN和Yahoo可以在robots.txt中使用一個額外的 「Crawl-delay」參數來指明請求之間的延遲。
#
# 一個並列爬蟲是並列執行多個行程的爬蟲。它的目標是最大化下載的速度，同時儘量減少並列的開銷和下載重複的頁面。為了避免下載一個頁面兩次，爬蟲系統需要策略來處理爬蟲執行時新發現的URL，因為同一個URL位址，可能被不同的爬蟲行程抓到。

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# 外部連結: [網路機器人] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA
# 外部連結: [網路] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [robots.txt] /wiki/Robots.txt
# 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# 外部連結: [HTML] /wiki/HTML
# 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
def WikiArticle(key_word_link, key_word, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
#         contentWord = "";
#         for i in content:
#             contentWord += i.text;
#         fh.write(contentWord)
#         fh.close()

        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        external_link_dict = dict({})
        for ext_link in content:
            a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
            if len(a_tag) > 0:
                for link_string in a_tag:
                    a_link = link_string["href"]       # 外部連結的網址
                    a_keyword = link_string.get_text()  # 外部連結的中文名稱
                    external_link_dict[a_keyword] = a_link
                    
#         #
#         # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
#         #
        if (len(external_link_dict) > 0):
            
            recursive = recursive + 1  # 遞迴深度加1
            
            for k, v in external_link_dict.items():
                WikiArticle(v, k, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 3

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2 (網路爬蟲)
# 遞迴層[1] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[2] - /wiki/%E5%9B%A0%E7%89%B9%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/20%E4%B8%96%E7%B4%80 (20世紀)
# 遞迴層[3] - /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C (電腦網路)
# 遞迴層[3] - /wiki/%E7%B6%B2%E8%B7%AF (網路)
# 遞迴層[3] - /wiki/%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE (網路協定)
# 遞迴層[3] - /wiki/%E5%AD%B8%E8%A1%93%E7%95%8C (學術界)
# 遞迴層[3] - /wiki/%E7%94%B5%E5%AD%90%E6%8A%80%E6%9C%AF (電子)
# 遞迴層[3] - /wiki/%E7%84%A1%E7%B7%9A (無線)
# 遞迴層[3] - /wiki/%E5%85%89%E7%BA%96%E7%B6%B2%E8%B7%AF (光纖網路技術)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[3] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[3] - /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 (電子郵件)
# 遞迴層[3] - /wiki/%E7%B6%B2%E9%9A%9B%E5%8D%94%E8%AD%B0%E9%80%9A%E8%A9%B1%E6%8A%80%E8%A1%93 (通話)
# 遞迴層[3] - /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB (檔案分享)
# 遞迴層[3] - /wiki/TCP/IP (TCP/IP)
# 遞迴層[3] - /wiki/%E5%88%86%E6%95%A3%E7%BD%91%E7%BB%9C (分散網路)
# 遞迴層[3] - /wiki/%E6%8E%92%E9%98%9F%E8%AE%BA (排隊論)
# 遞迴層[3] - /wiki/%E5%B0%81%E5%8C%85%E4%BA%A4%E6%8F%9B (封包交換)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8 (美國國防部)
# 遞迴層[3] - /wiki/%E5%9C%8B%E9%98%B2%E9%AB%98%E7%AD%89%E7%A0%94%E7%A9%B6%E8%A8%88%E5%8A%83%E7%BD%B2 (高等研究計劃署)
# 遞迴層[3] - /wiki/%E5%86%B7%E6%88%98 (冷戰)
# 遞迴層[3] - /wiki/ARPANET (ARPA網)
# 遞迴層[3] - /wiki/%E8%8B%B1%E5%9B%BD (英國)
# 遞迴層[3] - /wiki/%E6%8C%AA%E5%A8%81 (挪威)
# 遞迴層[3] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA (電腦)
# 遞迴層[3] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E6%81%A9 (羅伯特·卡恩)
# 遞迴層[3] - /wiki/%E6%96%87%E9%A0%93%C2%B7%E7%91%9F%E5%A4%AB (文頓·瑟夫)
# 遞迴層[3] - /wiki/TCP/IP%E5%8D%8F%E8%AE%AE (TCP/IP協定)
# 遞迴層[3] - /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96 (圖靈獎)
# 遞迴層[3] - /wiki/%E7%BD%91%E7%BB%9C%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE (NCP)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E5%9F%BA%E9%87%91%E4%BC%9A (美國國家科學基金會)
# 遞迴層[3] - /wiki/Usenet (Usenet)
# 遞迴層[3] - /wiki/Bitnet (Bitnet)
# 遞迴層[3] - /wiki/X.25 (X.25)
# 遞迴層[3] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[3] - /wiki/%E7%91%9E%E5%A3%AB (瑞士)
# 遞迴層[3] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究組織)
# 遞迴層[3] - /wiki/HTML (HTML)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (HTTP)
# 遞迴層[3] - /wiki/FidoNet (FidoNet)
# 遞迴層[3] - /wiki/%E7%BE%8E%E8%81%94%E7%A4%BE (美聯社)
# 遞迴層[3] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (web)
# 遞迴層[3] - /wiki/%E7%BA%BD%E7%BA%A6%E6%97%B6%E6%8A%A5 (紐約時報)
# 遞迴層[3] - /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF%E5%8D%94%E5%AE%9A (網際網路協定)
# 遞迴層[3] - /wiki/IPv4 (IPv4)
# 遞迴層[3] - /wiki/IP%E5%9C%B0%E5%9D%80 (IP位址)
# 遞迴層[3] - /wiki/IPv6 (IPv6)
# 遞迴層[3] - /wiki/%E7%94%A8%E6%88%B7%E6%95%B0%E6%8D%AE%E6%8A%A5%E5%8D%8F%E8%AE%AE (UDP協定)
# 遞迴層[3] - /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE (TCP協定)
# 遞迴層[3] - /wiki/%E7%94%A8%E6%88%B7%E6%95%B0%E6%8D%AE%E6%8A%A5%E5%8D%8F%E8%AE%AE (UDP)
# 遞迴層[3] - /wiki/%E6%96%87%E4%BB%B6%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (FTP)
# 遞迴層[3] - /wiki/%E6%92%A5%E8%99%9F%E9%80%A3%E7%B7%9A (電話撥號)
# 遞迴層[3] - /wiki/%E6%83%A1%E6%84%8F%E8%BB%9F%E9%AB%94 (惡意軟體)
# 遞迴層[3] - /wiki/%E9%9B%BB%E8%85%A6%E7%97%85%E6%AF%92 (電腦病毒)
# 遞迴層[3] - /wiki/%E9%9B%BB%E8%85%A6%E8%A0%95%E8%9F%B2 (電腦蠕蟲)
# 遞迴層[3] - /wiki/%E9%98%BB%E6%96%B7%E6%9C%8D%E5%8B%99%E6%94%BB%E6%93%8A (阻斷服務攻擊)
# 遞迴層[3] - /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94 (勒索軟體)
# 遞迴層[3] - /wiki/%E6%AE%AD%E5%B1%8D%E7%B6%B2%E7%B5%A1 (殭屍網路)
# 遞迴層[3] - /wiki/%E9%96%93%E8%AB%9C%E8%BB%9F%E4%BB%B6 (間諜軟體)
# 遞迴層[3] - /wiki/%E7%94%B5%E8%84%91%E7%8A%AF%E7%BD%AA (網路犯罪)
# 遞迴層[3] - /wiki/%E8%85%BE%E8%AE%AFQQ (騰訊QQ)
# 遞迴層[3] - /wiki/Skype (Skype)
# 遞迴層[3] - /wiki/%E7%A1%AC%E4%BB%B6 (硬體)
# 遞迴層[3] - /wiki/%E9%98%B2%E7%81%AB%E5%A2%99 (防火牆)
# 遞迴層[3] - /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD (中華人民共和國)
# 遞迴層[3] - /wiki/%E6%B2%99%E7%89%B9%E9%98%BF%E6%8B%89%E4%BC%AF (沙烏地阿拉伯)
# 遞迴層[3] - /wiki/%E6%94%BF%E6%B2%BB (政治)
# 遞迴層[3] - /wiki/%E5%AE%97%E6%95%99 (宗教)
# 遞迴層[3] - /wiki/%E4%BF%A1%E6%81%AF%E6%8A%80%E6%9C%AF (資訊科技)
# 遞迴層[3] - /wiki/%E6%9C%9D%E9%B2%9C (朝鮮)
# 遞迴層[3] - /wiki/%E9%98%B2%E7%81%AB%E9%95%BF%E5%9F%8E (防火長城)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9C%8B%E5%9C%8B%E5%AE%B6%E5%AE%89%E5%85%A8%E5%B1%80 (美國國家安全域)
# 遞迴層[3] - /wiki/%E4%B8%AD%E6%83%85%E5%B1%80 (中情局)
# 遞迴層[3] - /wiki/%E7%88%B1%E5%BE%B7%E5%8D%8E%C2%B7%E6%96%AF%E8%AF%BA%E7%99%BB (史諾登)
# 遞迴層[3] - /wiki/%E8%A1%9B%E5%A0%B1 (衛報)
# 遞迴層[3] - /wiki/%E8%8F%AF%E7%9B%9B%E9%A0%93%E9%83%B5%E5%A0%B1 (華盛頓郵報)
# 遞迴層[3] - /wiki/%E7%B6%93%E6%BF%9F%E5%90%88%E4%BD%9C%E7%99%BC%E5%B1%95%E7%B5%84%E7%B9%94 (經濟合作發展組織)
# 遞迴層[3] - /wiki/%E5%86%B0%E5%B3%B6 (冰島)
# 遞迴層[3] - /wiki/%E9%9F%A9%E5%9B%BD (韓國)
# 遞迴層[3] - /wiki/%E8%8D%B7%E8%98%AD (荷蘭)
# 遞迴層[3] - /wiki/%E4%B8%B9%E9%BA%A5 (丹麥)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9C%8B (美國)
# 遞迴層[3] - /wiki/%E4%B8%AD%E5%9B%BD%E4%BA%92%E8%81%94%E7%BD%91%E7%BB%9C%E4%BF%A1%E6%81%AF%E4%B8%AD%E5%BF%83 (中國互聯網絡信息中心)
# 遞迴層[3] - /wiki/%E7%BD%91%E6%B0%91 (網友)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[3] - /wiki/%E9%9B%BB%E8%85%A6%E9%A1%AF%E7%A4%BA%E5%99%A8 (電腦顯示器)
# 遞迴層[3] - /wiki/%E9%9B%BB%E5%AD%90%E8%A8%AD%E5%82%99 (電子裝置)
# 遞迴層[3] - /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 (超連結)
# 遞迴層[3] - /wiki/%E8%B1%AA%E5%B0%94%E8%B5%AB%C2%B7%E8%B7%AF%E6%98%93%E6%96%AF%C2%B7%E5%8D%9A%E5%B0%94%E8%B5%AB%E6%96%AF (豪爾赫·路易斯·博爾赫斯)
# 遞迴層[3] - /wiki/%E7%9F%AD%E7%AF%87%E5%B0%8F%E8%AA%AA (短篇小說)
# 遞迴層[3] - /wiki/%E4%B8%87%E5%B0%BC%E7%93%A6%E5%B0%94%C2%B7%E5%B8%83%E4%BB%80 (萬尼瓦爾·布希)
# 遞迴層[3] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[3] - /wiki/%E5%8A%9F%E7%B8%BE%E5%8B%B3%E7%AB%A0_(%E8%8B%B1%E5%9C%8B) (OM)
# 遞迴層[3] - /wiki/%E5%B7%B4%E6%96%AF%E5%8B%8B%E7%AB%A0 (KBE)
# 遞迴層[3] - /wiki/%E7%9A%87%E5%AE%B6%E5%AD%B8%E6%9C%83%E9%99%A2%E5%A3%AB (FRS)
# 遞迴層[3] - /wiki/%E7%9A%87%E5%AE%B6%E5%B7%A5%E7%A8%8B%E9%99%A2 (FREng)
# 遞迴層[3] - /wiki/%E7%9A%87%E5%AE%B6%E6%96%87%E8%89%BA%E5%AD%A6%E4%BC%9A (FRSA)
# 遞迴層[3] - /wiki/%E8%8B%B1%E5%9C%8B%E9%9B%BB%E8%85%A6%E5%AD%B8%E6%9C%83 (FBCS)
# 遞迴層[3] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (超文字傳輸協定)
# 遞迴層[3] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F (全球資訊網協會)
# 遞迴層[3] - /wiki/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%A6%E9%99%A2%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%A7%91%E5%AD%A6%E5%8F%8A%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD%E5%AE%9E%E9%AA%8C%E5%AE%A4 (麻省理工學院電腦科學及人工智慧實驗室)
# 遞迴層[3] - /wiki/%E7%A6%8F%E7%89%B9%E5%9F%BA%E9%87%91%E6%9C%83 (福特基金會)
# 遞迴層[3] - /wiki/%E4%BC%8A%E4%B8%BD%E8%8E%8E%E7%99%BD%E4%BA%8C%E4%B8%96 (伊麗莎白二世)
# 遞迴層[3] - /wiki/%E5%A4%A7%E8%8B%B1%E5%B8%9D%E5%9B%BD%E5%8B%8B%E7%AB%A0 (大英帝國爵級司令勳章)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E9%99%A2 (美國國家科學院)
# 遞迴層[3] - /wiki/%E6%99%82%E4%BB%A3_(%E9%9B%9C%E8%AA%8C) (時代)
# 遞迴層[3] - /wiki/%E6%97%B6%E4%BB%A3100%E4%BA%BA%EF%BC%9A%E6%9C%AC%E4%B8%96%E7%BA%AA%E6%9C%80%E9%87%8D%E8%A6%81%E7%9A%84%E4%BA%BA%E7%89%A9 (時代100人：本世紀最重要的人物)
# 遞迴層[3] - /wiki/2012%E5%B9%B4%E5%A4%8F%E5%AD%A3%E5%A5%A7%E6%9E%97%E5%8C%B9%E5%85%8B%E9%81%8B%E5%8B%95%E6%9C%83%E9%96%8B%E5%B9%95%E5%85%B8%E7%A6%AE (2012年夏季奧林匹克運動會開幕典禮)
# 遞迴層[3] - /wiki/NeXT (NeXT)
# 遞迴層[3] - /wiki/Twitter (Twitter)
# 遞迴層[3] - /wiki/%E6%B6%B2%E6%99%B6%E6%98%BE%E7%A4%BA%E5%99%A8 (液晶顯示器)
# 遞迴層[3] - /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96 (圖靈獎)
# 遞迴層[3] - /wiki/%E6%9B%BC%E5%88%87%E6%96%AF%E7%89%B91%E5%9E%8B (曼切斯特1型)
# 遞迴層[3] - /wiki/%E9%90%B5%E9%81%93%E8%BF%B7 (鐵道迷)
# 遞迴層[3] - /wiki/%E7%89%9B%E6%B4%A5%E5%A4%A7%E5%AD%A6%E7%8E%8B%E5%90%8E%E5%AD%A6%E9%99%A2 (牛津大學王后學院)
# 遞迴層[3] - /wiki/%E6%99%AE%E7%88%BE (普爾)
# 遞迴層[3] - /wiki/%E6%97%A5%E5%85%A7%E7%93%A6 (日內瓦)
# 遞迴層[3] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究組織)
# 遞迴層[3] - /wiki/%E7%8D%A8%E7%AB%8B%E5%90%88%E5%90%8C%E4%BA%BA (獨立承包人)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E7%B3%BB%E7%BB%9F (超文字系統)
# 遞迴層[3] - /wiki/ENQUIRE (ENQUIRE)
# 遞迴層[3] - /wiki/%E4%BC%AF%E6%81%A9%E8%8C%85%E6%96%AF (伯恩茅斯)
# 遞迴層[3] - /wiki/%E8%BF%9C%E7%A8%8B%E8%BF%87%E7%A8%8B%E8%B0%83%E7%94%A8 (遠端程序呼叫)
# 遞迴層[3] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%BD%91%E7%BB%9C (電腦網路)
# 遞迴層[3] - /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 (網頁瀏覽器)
# 遞迴層[3] - /wiki/WorldWideWeb (WorldWideWeb)
# 遞迴層[3] - /wiki/NeXTSTEP (NeXTSTEP)
# 遞迴層[3] - /wiki/CERN_httpd (CERN httpd)
# 遞迴層[3] - /wiki/%E5%AE%88%E6%8A%A4%E8%BF%9B%E7%A8%8B (守護行程)
# 遞迴層[3] - /wiki/%E7%BD%91%E7%AB%99 (網站)
# 遞迴層[3] - /wiki/%E5%8D%97%E5%AE%89%E6%99%AE%E6%95%A6%E5%A4%A7%E5%AD%A6 (南安普敦大學)
# 遞迴層[3] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 (語意網)
# 遞迴層[3] - /wiki/%E6%B3%B0%E6%99%A4%E5%A3%AB%E6%8A%A5 (泰晤士報)
# 遞迴層[3] - /wiki/%E6%88%88%E7%99%BB%C2%B7%E5%B8%83%E6%9C%97 (戈登·布朗)
# 遞迴層[3] - /wiki/%E8%8B%B1%E5%9C%8B%E5%9C%B0%E5%BD%A2%E6%B8%AC%E9%87%8F%E5%B1%80 (英國地形測量局)
# 遞迴層[3] - /wiki/%E7%BD%91%E7%BB%9C%E4%B8%AD%E7%AB%8B%E6%80%A7 (網路中立性)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E6%9C%8D%E5%8A%A1%E4%BE%9B%E5%BA%94%E5%95%86 (網際網路服務供應商)
# 遞迴層[2] - /wiki/CERN (CERN)
# 遞迴層[3] - /wiki/%E6%B3%95%E8%AF%AD (法語)
# 遞迴層[3] - /wiki/%E8%8B%B1%E6%96%87 (英文)
# 遞迴層[3] - /wiki/%E7%B2%92%E5%AD%90%E7%89%A9%E7%90%86%E5%AD%B8 (粒子物理學)
# 遞迴層[3] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[3] - /wiki/%E7%91%9E%E5%A3%AB (瑞士)
# 遞迴層[3] - /wiki/%E6%97%A5%E5%85%A7%E7%93%A6 (日內瓦)
# 遞迴層[3] - /wiki/%E6%B2%BB%E5%A4%96%E6%B3%95%E6%AC%8A (治外法權)
# 遞迴層[3] - /wiki/%E4%BB%A5%E8%89%B2%E5%88%97 (以色列)
# 遞迴層[3] - /wiki/%E6%AD%90%E6%B4%B2 (歐洲)
# 遞迴層[3] - /wiki/%E7%89%A9%E7%90%86%E5%AD%B8 (物理學)
# 遞迴層[3] - /wiki/%E7%B2%92%E5%AD%90%E5%8A%A0%E9%80%9F%E5%99%A8 (粒子加速器)
# 遞迴層[3] - /wiki/%E7%A7%91%E7%93%A6%E7%88%BE%E6%96%AF%E5%9F%BA (科瓦爾斯基)
# 遞迴層[3] - /wiki/%E6%B2%83%E7%B4%8D%C2%B7%E6%B5%B7%E6%A3%AE%E5%A0%A1 (沃納·海森堡)
# 遞迴層[3] - /wiki/ENQUIRE (詢問計劃)
# 遞迴層[3] - /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[3] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 (羅伯特·卡里奧)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[3] - /wiki/%E7%B6%B2%E6%A0%BC%E8%A8%88%E7%AE%97 (網格計算)
# 遞迴層[3] - /wiki/%E5%A4%A7%E5%9E%8B%E5%BC%B7%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F (大型強子對撞機)
# 遞迴層[3] - /wiki/%E5%A4%A7%E5%9E%8B%E9%9B%BB%E5%AD%90%E6%AD%A3%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F (大型電子正子對撞機)
# 遞迴層[3] - /wiki/%E6%97%A5%E5%86%85%E7%93%A6%E5%9B%BD%E9%99%85%E6%9C%BA%E5%9C%BA (日內瓦國際機場)
# 遞迴層[3] - /wiki/%E4%BE%8F%E7%BD%97%E5%B1%B1 (侏羅山)
# 遞迴層[3] - /wiki/%E7%B7%8A%E6%B9%8A%E7%B7%B2%E5%AD%90%E7%B7%9A%E5%9C%88 (緊湊緲子線圈)
# 遞迴層[3] - /wiki/%E8%B6%85%E7%92%B0%E9%9D%A2%E5%84%80%E5%99%A8 (超環面儀器)
# 遞迴層[3] - /wiki/LHCb (LHCb)
# 遞迴層[3] - /wiki/%E6%AF%94%E5%88%A9%E6%99%82 (比利時)
# 遞迴層[3] - /wiki/%E9%9B%BB%E8%85%A6 (電腦)
# 遞迴層[3] - /wiki/%E4%B8%B2%E6%B5%81 (串流)
# 遞迴層[3] - /wiki/%E5%AE%89%E7%9C%81 (安省)
# 遞迴層[3] - /wiki/%E5%A4%B8%E5%85%8B (魅夸克)
# 遞迴層[3] - /wiki/%E5%9C%B0%E7%90%86%E5%9D%90%E6%A0%87 (座標)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 (網頁瀏覽器)
# 遞迴層[3] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[3] - /wiki/%E6%87%89%E7%94%A8%E7%A8%8B%E5%BC%8F (應用程式)
# 遞迴層[3] - /wiki/%E7%B5%B1%E4%B8%80%E8%B3%87%E6%BA%90%E6%A8%99%E8%AA%8C%E7%AC%A6 (統一資源標誌符)
# 遞迴層[3] - /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 (超連結)
# 遞迴層[3] - /wiki/%E4%B8%93%E7%94%A8%E7%BD%91%E7%BB%9C (專用網路)
# 遞迴層[3] - /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 (網頁伺服器)
# 遞迴層[3] - /wiki/%E6%AA%94%E6%A1%88%E7%B3%BB%E7%B5%B1 (檔案系統)
# 遞迴層[3] - /wiki/Mozilla_Firefox (Mozilla Firefox)
# 遞迴層[3] - /wiki/Internet_Explorer_for_Mac (Internet Explorer)
# 遞迴層[3] - /wiki/Microsoft_Edge (Microsoft Edge)
# 遞迴層[3] - /wiki/Google_Chrome (Google Chrome)
# 遞迴層[3] - /wiki/Opera%E9%9B%BB%E8%85%A6%E7%80%8F%E8%A6%BD%E5%99%A8 (Opera)
# 遞迴層[3] - /wiki/Safari (Safari)
# 遞迴層[3] - /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[3] - /wiki/WorldWideWeb (WorldWideWeb)
# 遞迴層[3] - /wiki/%E5%A6%AE%E5%8F%AF%E6%8B%89%C2%B7%E4%BD%A9%E6%B4%9B (妮可拉·佩洛)
# 遞迴層[3] - /wiki/Line_Mode_Browser (LMB)
# 遞迴層[3] - /wiki/%E5%93%91%E7%BB%88%E7%AB%AF (啞終端)
# 遞迴層[3] - /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E5%AE%89%E5%BE%B7%E6%A3%AE (馬克·安德森)
# 遞迴層[3] - /wiki/Mosaic (Mosaic)
# 遞迴層[3] - /wiki/NCSA (NCSA)
# 遞迴層[3] - /wiki/Netscape (Netscape)
# 遞迴層[3] - /wiki/Netscape_Navigator (Netscape Navigator)
# 遞迴層[3] - /wiki/%E5%BE%AE%E8%BB%9F (微軟)
# 遞迴層[3] - /wiki/Spyglass%E5%85%AC%E5%8F%B8 (Spyglass公司)
# 遞迴層[3] - /wiki/%E6%B5%8F%E8%A7%88%E5%99%A8%E5%A4%A7%E6%88%98 (瀏覽器大戰)
# 遞迴層[3] - /wiki/Windows (Windows)
# 遞迴層[3] - /wiki/%E9%96%8B%E6%94%BE%E5%8E%9F%E5%A7%8B%E7%A2%BC (開放原始碼)
# 遞迴層[3] - /wiki/Mozilla_Application_Suite (Mozilla Application Suite)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9C%8B%E7%B7%9A%E4%B8%8A (美國線上)
# 遞迴層[3] - /wiki/Mozilla_Firefox (Phoenix)
# 遞迴層[3] - /wiki/Macintosh (Macintosh)
# 遞迴層[3] - /wiki/Firefox (Firefox)
# 遞迴層[3] - /wiki/IPad (iPad)
# 遞迴層[3] - /wiki/IPhone (iPhone)
# 遞迴層[3] - /wiki/Konqueror (Konqueror)
# 遞迴層[3] - /wiki/KHTML (KHTML)
# 遞迴層[3] - /wiki/%E6%8E%92%E7%89%88%E5%BC%95%E6%93%8E (排版引擎)
# 遞迴層[3] - /wiki/OS_X (OS X)
# 遞迴層[3] - /wiki/%E6%90%9C%E5%B0%8B%E5%BC%95%E6%93%8E (搜尋引擎)
# 遞迴層[3] - /wiki/Google (Google)
# 遞迴層[3] - /wiki/StatCounter (StatCounter)
# 遞迴層[3] - /wiki/%E7%B6%B2%E7%B5%A1%E5%A5%97%E4%BB%B6 (網路套件)
# 遞迴層[3] - /wiki/%E5%BC%B9%E5%87%BA%E5%BC%8F%E5%B9%BF%E5%91%8A (彈出式廣告)
# 遞迴層[3] - /wiki/HTTPS (HTTPS)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (HTTP)
# 遞迴層[3] - /wiki/Cookie (Cookie)
# 遞迴層[3] - /wiki/%E7%80%8F%E8%A6%BD%E5%99%A8%E6%93%B4%E5%85%85%E5%8A%9F%E8%83%BD (瀏覽器擴充功能)
# 遞迴層[3] - /wiki/%E9%9A%90%E7%A7%81%E7%8D%BE (防止廣告聯盟)
# 遞迴層[2] - /wiki/%E8%B3%87%E8%A8%8A%E6%99%82%E4%BB%A3 (資訊時代)
# 遞迴層[3] - /wiki/%E4%BF%A1%E6%81%AF%E4%BA%A7%E4%B8%9A (資訊工業)
# 遞迴層[3] - /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC (馬克·祖克柏)
# 遞迴層[3] - /wiki/Facebook (Facebook)
# 遞迴層[2] - /wiki/%E7%BD%91%E9%A1%B5 (網頁)
# 遞迴層[3] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[3] - /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 (網頁瀏覽器)
# 遞迴層[3] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA (電腦)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/%E7%B6%B2%E5%9D%80 (網址)
# 遞迴層[3] - /wiki/URL (URL)
# 遞迴層[3] - /wiki/HTML (HTML)
# 遞迴層[3] - /wiki/%E5%9C%96%E5%83%8F (圖像)
# 遞迴層[3] - /wiki/%E7%B6%B2%E7%AB%99 (網站)
# 遞迴層[3] - /wiki/%E9%A6%96%E9%A0%81 (首頁)
# 遞迴層[3] - /wiki/%E6%96%87%E5%AD%97%E7%B7%A8%E8%BC%AF%E5%99%A8 (文字編輯器)
# 遞迴層[3] - /wiki/HTML%E7%B7%A8%E8%BC%AF%E5%99%A8 (HTML編輯器)
# 遞迴層[3] - /wiki/FTP (FTP)
# 遞迴層[3] - /wiki/%E4%B8%8A%E8%BC%89 (上傳)
# 遞迴層[2] - /wiki/%E6%A0%BC%E5%BC%8F%E5%8C%96%E6%96%87%E6%9C%AC (格式化)
# 遞迴層[3] - /wiki/%E8%8B%B1%E6%96%87 (英文)
# 遞迴層[3] - /wiki/%E7%BA%AF%E6%96%87%E6%9C%AC (純文本)
# 遞迴層[3] - /wiki/%E8%B6%85%E9%93%BE%E6%8E%A5 (超連結)
# 遞迴層[3] - /wiki/HTML (HTML)
# 遞迴層[3] - /wiki/Rich_Text_Format (RTF)
# 遞迴層[3] - /wiki/UTF-8 (UTF-8)
# 遞迴層[3] - /wiki/%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 (標記語言)
# 遞迴層[3] - /wiki/Microsoft_Word (Microsoft Word)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E4%BB%B6%E6%A8%99%E7%A4%BA%E8%AA%9E%E8%A8%80 (超文件標示語言)
# 遞迴層[3] - /wiki/%E7%BD%91%E9%A1%B5 (網頁)
# 遞迴層[3] - /wiki/%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 (標記語言)
# 遞迴層[3] - /wiki/%E5%B1%82%E5%8F%A0%E6%A0%B7%E5%BC%8F%E8%A1%A8 (CSS)
# 遞迴層[3] - /wiki/JavaScript (JavaScript)
# 遞迴層[3] - /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 (網頁瀏覽器)
# 遞迴層[3] - /wiki/%E7%BC%96%E7%A8%8B%E8%AF%AD%E8%A8%80 (程式語言)
# 遞迴層[3] - /wiki/HTML%E5%85%83%E7%B4%A0 (HTML元素)
# 遞迴層[3] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 (語意)
# 遞迴層[3] - /wiki/%E6%8B%AC%E5%8F%B7 (尖括號)
# 遞迴層[3] - /wiki/%E8%84%9A%E6%9C%AC%E8%AF%AD%E8%A8%80 (手稿語言)
# 遞迴層[3] - /wiki/%E5%B1%82%E5%8F%A0%E6%A0%B7%E5%BC%8F%E8%A1%A8 (階層式樣式表)
# 遞迴層[3] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F (全球資訊網協會)
# 遞迴層[3] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[3] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究中心)
# 遞迴層[3] - /wiki/ENQUIRE (ENQUIRE)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[3] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 (羅伯特·卡里奧)
# 遞迴層[3] - /wiki/SGML (標準通用標記語言)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%B7%A5%E7%A8%8B%E4%BB%BB%E5%8A%A1%E7%BB%84 (網際網路工程任務組)
# 遞迴層[3] - /wiki/%E6%96%87%E6%A1%A3%E7%B1%BB%E5%9E%8B%E5%AE%9A%E4%B9%89 (文件類型定義)
# 遞迴層[3] - /wiki/NCSA_Mosaic (NCSA Mosaic)
# 遞迴層[3] - /wiki/%E5%9C%8B%E9%9A%9B%E6%A8%99%E6%BA%96%E5%8C%96%E7%B5%84%E7%B9%94 (ISO)
# 遞迴層[3] - /wiki/IEC (IEC)
# 遞迴層[3] - /wiki/%E7%B6%B2%E9%A0%81%E8%B6%85%E6%96%87%E6%9C%AC%E6%8A%80%E8%A1%93%E5%B7%A5%E4%BD%9C%E5%B0%8F%E7%B5%84 (網頁超文字應用技術工作小組)
# 遞迴層[3] - /wiki/XML (XML)
# 遞迴層[3] - /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F (標準模式)
# 遞迴層[3] - /wiki/Hello_World (Hello World)
# 遞迴層[3] - /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F (怪異模式)
# 遞迴層[3] - /wiki/%E6%8F%9B%E8%A1%8C (換行)
# 遞迴層[3] - /wiki/%E9%98%BF%E6%8B%89%E4%BC%AF%E8%AF%AD (阿拉伯語)
# 遞迴層[3] - /wiki/%E6%B3%A2%E6%96%AF%E8%AF%AD (波斯語)
# 遞迴層[3] - /wiki/%E5%B8%8C%E4%BC%AF%E6%9D%A5%E8%AF%AD (希伯來語)
# 遞迴層[3] - /wiki/%E5%AD%97%E5%85%83%E5%80%BC%E5%8F%83%E8%80%83 (字元值參考)
# 遞迴層[3] - /wiki/%E7%94%A8%E6%88%B7%E4%BB%A3%E7%90%86 (用戶代理)
# 遞迴層[3] - /wiki/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB (搜尋和索引)
# 遞迴層[3] - /wiki/%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81 (字元編碼)
# 遞迴層[3] - /wiki/UTF-8 (UTF-8)
# 遞迴層[3] - /wiki/Unicode (Unicode)
# 遞迴層[3] - /wiki/%E6%95%B8%E6%93%9A%E9%A1%9E%E5%9E%8B (資料類型)
# 遞迴層[3] - /wiki/HTML5 (HTML5)
# 遞迴層[3] - /wiki/Span_and_div (span與div)
# 遞迴層[3] - /wiki/%E5%91%88%E7%8E%B0%E4%B8%8E%E5%86%85%E5%AE%B9%E5%88%86%E7%A6%BB (呈現與內容分離)
# 遞迴層[3] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 (語意網)
# 遞迴層[3] - /wiki/Web_2.0 (Web 2.0)
# 遞迴層[3] - /wiki/%E6%B7%B7%E6%90%AD_(%E4%BA%92%E8%81%AF%E7%B6%B2) (混搭)
# 遞迴層[3] - /wiki/%E6%A0%BC%E5%83%B9 (價格比較網站)
# 遞迴層[3] - /wiki/%E8%81%9A%E5%90%88%E5%99%A8 (聚合)
# 遞迴層[3] - /wiki/%E7%B6%B2%E9%A0%81%E9%96%8B%E7%99%BC%E8%80%85 (網頁開發者)
# 遞迴層[3] - /wiki/API (API)
# 遞迴層[3] - /wiki/%E7%B6%B2%E8%B7%AF%E8%9C%98%E8%9B%9B (網路爬蟲)
# 遞迴層[3] - /wiki/%E7%AE%97%E6%B3%95 (演算法)
# 遞迴層[3] - /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E (搜尋工具)
# 遞迴層[3] - /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 (網頁伺服器)
# 遞迴層[3] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (超文字傳輸協定)
# 遞迴層[3] - /wiki/%E7%94%B5%E5%AD%90%E9%82%AE%E4%BB%B6 (電子郵件)
# 遞迴層[3] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[3] - /wiki/HTTP (HTTP)
# 遞迴層[3] - /wiki/%E6%96%87%E4%BB%B6%E9%A1%9E%E5%9E%8B (檔案類型)
# 遞迴層[3] - /wiki/%E5%85%83%E6%95%B0%E6%8D%AE (元資料)
# 遞迴層[3] - /wiki/MIME (MIME)
# 遞迴層[3] - /wiki/HTML%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81 (HTML字元編碼)
# 遞迴層[3] - /wiki/%E8%AF%AD%E6%B3%95%E9%94%99%E8%AF%AF (語法錯誤)
# 遞迴層[3] - /wiki/%E7%BA%AF%E6%96%87%E6%9C%AC (純文字)
# 遞迴層[3] - /wiki/%E5%9B%BE%E5%BD%A2%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2 (圖形化使用者介面)
# 遞迴層[3] - /wiki/%E9%92%93%E9%B1%BC%E5%BC%8F%E6%94%BB%E5%87%BB (釣魚攻擊)
# 遞迴層[3] - /wiki/%E5%9E%83%E5%9C%BE%E9%9B%BB%E9%83%B5 (垃圾郵件)
# 遞迴層[3] - /wiki/%E6%96%87%E4%BB%B6%E6%89%A9%E5%B1%95%E5%90%8D (副檔名)
# 遞迴層[3] - /wiki/DOS (DOS)
# 遞迴層[3] - /wiki/FAT (FAT)
# 遞迴層[3] - /wiki/8.3 (3個字母)
# 遞迴層[3] - /wiki/Microsoft_Windows (Microsoft Windows)
# 遞迴層[3] - /wiki/Cookie (Cookie)
# 遞迴層[3] - /wiki/%E6%B3%A8%E5%86%8C%E8%A1%A8 (登錄檔)
# 遞迴層[3] - /wiki/EXE%E6%A0%BC%E5%BC%8F (EXE檔案)
# 遞迴層[3] - /wiki/%E6%89%80%E8%A6%8B%E5%8D%B3%E6%89%80%E5%BE%97 (所見即所得)
# 遞迴層[3] - /wiki/%E6%96%87%E5%AD%97%E5%A4%84%E7%90%86%E5%99%A8 (文書處理器)
# 遞迴層[3] - /wiki/WYSIWYM (WYSIWYM)
# 遞迴層[2] - /wiki/%E5%9C%96%E7%89%87 (圖片)
# 遞迴層[3] - /wiki/%E7%85%A7%E7%9B%B8%E6%9C%BA (照相機)
# 遞迴層[3] - /wiki/%E9%95%9C%E5%AD%90 (鏡子)
# 遞迴層[3] - /wiki/%E6%9C%9B%E8%BF%9C%E9%95%9C (望遠鏡)
# 遞迴層[3] - /wiki/%E6%98%BE%E5%BE%AE%E9%95%9C (顯微鏡)
# 遞迴層[3] - /wiki/%E6%95%B0%E5%AD%97%E5%9B%BE%E5%83%8F (數位影像)
# 遞迴層[3] - /wiki/%E5%9B%BE%E5%83%8F%E5%88%86%E6%9E%90 (圖像分析)
# 遞迴層[3] - /wiki/%E5%9B%BE%E5%83%8F%E5%A4%84%E7%90%86 (圖像處理)
# 遞迴層[3] - /wiki/%E5%9C%96%E7%89%87 (圖片)
# 遞迴層[3] - /wiki/%E7%85%A7%E7%89%87 (相片)
# 遞迴層[3] - /wiki/%E5%BD%B1%E7%89%87 (影片)
# 遞迴層[2] - /wiki/%E5%BD%B1%E7%89%87 (影片)
# 遞迴層[2] - /wiki/%E8%81%B2%E9%9F%B3 (聲音)
# 遞迴層[3] - /wiki/%E5%A3%B0%E6%B3%A2 (聲波)
# 遞迴層[3] - /wiki/%E4%BB%8B%E8%B4%A8 (介質)
# 遞迴層[3] - /wiki/%E7%A9%BA%E6%B0%A3 (氣體)
# 遞迴層[3] - /wiki/%E5%9B%BA%E4%BD%93 (固體)
# 遞迴層[3] - /wiki/%E6%B6%B2%E4%BD%93 (液體)
# 遞迴層[3] - /wiki/%E5%90%AC%E8%A7%89 (聽覺)
# 遞迴層[3] - /wiki/%E5%99%A8%E5%AE%98 (器官)
# 遞迴層[3] - /wiki/%E6%B3%A2%E5%8B%95 (波動)
# 遞迴層[3] - /wiki/%E8%B5%AB%E8%8C%B2 (赫茲)
# 遞迴層[3] - /wiki/%E5%88%86%E8%B2%9D (分貝)
# 遞迴層[3] - /wiki/%E5%A3%B0%E5%AD%A6 (聲學)
# 遞迴層[3] - /wiki/%E7%A9%BA%E6%B0%A3 (空氣)
# 遞迴層[3] - /wiki/%E9%9F%B3%E9%9F%BF%E5%B7%A5%E7%A8%8B (音響工程)
# 遞迴層[3] - /wiki/%E8%81%B2%E9%9F%B3%E4%BF%A1%E8%99%9F%E8%99%95%E7%90%86 (聲音信號處理)
# 遞迴層[3] - /wiki/%E5%BB%BA%E7%AD%91%E5%A3%B0%E5%AD%A6 (建築聲學)
# 遞迴層[3] - /wiki/%E5%BF%83%E7%90%86%E5%A3%B0%E5%AD%A6 (心理聲學)
# 遞迴層[3] - /wiki/%E8%AA%AA%E8%A9%B1 (說話)
# 遞迴層[3] - /wiki/%E8%B6%85%E5%A3%B0%E6%B3%A2 (超音波)
# 遞迴層[3] - /wiki/%E6%8C%AF%E5%8B%95 (振動)
# 遞迴層[3] - /wiki/%E4%B9%90%E5%99%A8 (樂器)
# 遞迴層[3] - /wiki/%E9%A0%BB%E7%8E%87 (頻率)
# 遞迴層[3] - /wiki/%E5%BC%BA%E5%BA%A6 (強度)
# 遞迴層[3] - /wiki/%E6%AD%A3%E5%BC%A6%E6%B3%A2 (正弦波)
# 遞迴層[3] - /wiki/%E5%82%85%E7%AB%8B%E5%8F%B6%E5%8F%98%E6%8D%A2 (傅立葉變換)
# 遞迴層[3] - /wiki/%E6%AC%A1%E5%A3%B0%E6%B3%A2 (次聲波)
# 遞迴層[3] - /wiki/%E6%B3%A2%E9%95%B7 (波長)
# 遞迴層[3] - /wiki/%E5%8F%8D%E5%B0%84 (反射)
# 遞迴層[3] - /wiki/%E6%8A%98%E5%B0%84 (折射)
# 遞迴層[3] - /wiki/%E5%B9%B2%E6%B6%89 (干涉)
# 遞迴層[3] - /wiki/%E7%B9%9E%E5%B0%84 (繞射)
# 遞迴層[3] - /wiki/%E6%95%A3%E5%B0%84 (散射)
# 遞迴層[3] - /wiki/%E6%AD%A3%E5%BC%A6%E6%9B%B2%E7%B7%9A (正弦)
# 遞迴層[3] - /wiki/%E5%B9%B3%E9%9D%A2%E6%B3%A2 (平面波)
# 遞迴層[3] - /wiki/%E6%A0%87%E5%87%86%E7%8A%B6%E5%86%B5 (標準狀況)
# 遞迴層[3] - /wiki/%E9%80%9F%E5%BA%A6 (速度)
# 遞迴層[3] - /wiki/%E5%90%91%E9%87%8F (向量)
# 遞迴層[3] - /wiki/%E6%B3%A2%E7%9F%A2 (波向量)
# 遞迴層[3] - /wiki/%E6%A8%AA%E6%B3%A2 (橫波)
# 遞迴層[3] - /wiki/%E5%89%AA%E6%87%89%E5%8A%9B (剪應力)
# 遞迴層[3] - /wiki/%E5%81%8F%E6%8C%AF (偏振)
# 遞迴層[3] - /wiki/%E5%A3%B0%E9%80%9F (聲速)
# 遞迴層[3] - /wiki/%E8%BF%9E%E7%BB%AD%E4%BB%8B%E8%B4%A8%E5%8A%9B%E5%AD%A6 (連續介質力學)
# 遞迴層[3] - /wiki/%E7%B6%93%E5%85%B8%E5%8A%9B%E5%AD%B8 (古典力學)
# 遞迴層[3] - /wiki/%E4%B8%8D%E5%8F%AF%E5%A3%93%E7%B8%AE%E7%8E%87 (不可壓縮率)
# 遞迴層[3] - /wiki/%E5%AF%86%E5%BA%A6 (密度)
# 遞迴層[3] - /wiki/%E7%B5%95%E7%86%B1 (絕熱)
# 遞迴層[3] - /wiki/%E7%90%86%E6%83%B3%E6%B0%94%E4%BD%93 (理想氣體)
# 遞迴層[3] - /wiki/%E7%94%9F%E7%90%86%E5%AD%B8 (生理學)
# 遞迴層[3] - /wiki/%E5%BF%83%E7%90%86%E5%AD%B8 (心理學)
# 遞迴層[3] - /wiki/%E8%B5%AB%E5%85%B9 (Hz)
# 遞迴層[3] - /wiki/%E7%89%A9%E7%A8%AE (物種)
# 遞迴層[3] - /wiki/%E5%B0%8E%E8%88%AA (導航)
# 遞迴層[3] - /wiki/%E6%8D%95%E9%A3%9F (捕食)
# 遞迴層[3] - /wiki/%E8%9B%99 (蛙)
# 遞迴層[3] - /wiki/%E9%B3%A5 (鳥)
# 遞迴層[3] - /wiki/%E5%93%BA%E4%B9%B3%E5%8B%95%E7%89%A9 (哺乳動物)
# 遞迴層[3] - /wiki/%E8%9A%8A%E9%9F%B3 (蚊音)
# 遞迴層[3] - /wiki/%E5%8E%8B%E5%BC%BA (壓力)
# 遞迴層[3] - /wiki/%E5%9D%87%E6%96%B9%E6%A0%B9 (均方根)
# 遞迴層[3] - /wiki/%E5%B8%95%E6%96%AF%E5%8D%A1 (Pa)
# 遞迴層[3] - /wiki/%E5%93%8D%E5%BA%94%E7%8E%87 (響應率)
# 遞迴層[3] - /wiki/%E5%9B%BD%E9%99%85%E7%94%B5%E5%B7%A5%E5%A7%94%E5%91%98%E4%BC%9A (國際電工委員會)
# 遞迴層[3] - /wiki/%E5%B7%A5%E4%B8%9A (工業)
# 遞迴層[3] - /wiki/%E5%86%9B%E4%BA%8B (軍事)
# 遞迴層[3] - /wiki/%E9%86%AB%E7%99%82 (醫療)
# 遞迴層[3] - /wiki/%E6%BD%9C%E8%89%87 (潛艇)
# 遞迴層[3] - /wiki/%E5%A3%B0%E5%91%90 (聲吶)
# 遞迴層[3] - /wiki/%E8%83%86%E7%BB%93%E7%9F%B3 (膽結石)
# 遞迴層[3] - /wiki/%E7%81%AB%E5%B1%B1%E7%88%86%E7%99%BC (火山爆發)
# 遞迴層[3] - /wiki/%E9%BE%99%E5%8D%B7%E9%A3%8E (龍捲風)
# 遞迴層[3] - /wiki/%E9%9B%B7%E6%9A%B4 (雷暴)
# 遞迴層[3] - /wiki/%E5%8F%B0%E9%A3%8E (颱風)
# 遞迴層[3] - /wiki/%E6%A0%B8%E8%AF%95%E9%AA%8C (核試驗)
# 遞迴層[3] - /wiki/%E7%81%AB%E7%AE%AD (火箭)
# 遞迴層[3] - /wiki/%E5%A3%B0%E5%8E%8B (聲壓)
# 遞迴層[3] - /wiki/%E9%AB%98%E8%A1%80%E5%8E%8B (高血壓)
# 遞迴層[3] - /wiki/%E7%9D%A1%E7%9C%A0 (睡眠)
# 遞迴層[3] - /wiki/%E5%9B%9E%E9%9F%B3 (回音)
