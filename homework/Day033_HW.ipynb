# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 尚未登入
response = requests.get('https://github.com/new')
response.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aea5d706af72> in <module>()
#       1 # 尚未登入
# ----> 2 response = requests.get('https://github.com/new')
#       3 response.text
#
# NameError: name 'requests' is not defined

# %%
# logged_in
formData = {'commit': 'Sign in',
'utf8': '✓',
'authenticity_token': 'zhCqP/Nt8+eeHZfP4xY1dMIf1F5nfGrq0nMb1UawC06pjD0SQTGSq+yqIN6hXEsuN7Xfbhe1FjR/YUDFT0dCBA==',
'ga_id': '547724160.1581834827',
'login': '',
'password': '',
'webauthn-support': 'supported',
'webauthn-iuvpaa-support':'unsupported',
'required_field_d2ba': '',
'timestamp': '1581835959346',
'timestamp_secret': '3706c25484377bcb00d6cf579cf066a20d0bbb63207c514e74ee054526384945'}



res = requests.get('https://github.com/session', verify = False, data = formData)
print(res.status_code)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\Users\jud40\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\jud40\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 200
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sign in to GitHub · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
# GitHub no longer supports this web browser.
#
#           Learn more about the browsers we support.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sign in to GitHub
#
#
#
#
#
# ...
